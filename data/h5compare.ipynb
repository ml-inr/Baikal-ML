# %%
import h5py as h5
import numpy as np
import torch

from root_manager.chunk_generator import ChunkGenerator
from root_manager.settings import ChunkGeneratorConfig, ProcessorConfig, FilterParams

# %%
path_to_root = "/net/62/home3/ivkhar/Baikal/data/initial_data/MC_2020/muatm/root/all/10762.root"
h5_file_path = "/net/62/home3/ivkhar/Baikal/data/h5s/baikal_mc2020_multi_split_0924.h5"

# %%
proc_cfg = ProcessorConfig(
    center_times= True, 
    calc_tres = False, 
    filter_cfg = FilterParams(
        only_signal = False,
        min_hits = 0,
        min_strings = 0,
        min_Q = 0,
        t_threshold = 100000
    )
)
chunk_generator_cfg=ChunkGeneratorConfig(
            chunk_size = 25,
            processor_params = proc_cfg,
            fields = ['PulsesAmpl', 'PulsesTime', 'Xrel', 'Yrel', 'Zrel', 'num_signal_hits', 'num_signal_strings', 'nu_induced'],
            shuffle_paths = False
        )

gen = ChunkGenerator([path_to_root], chunk_generator_cfg).get_chunks()
df = next(gen)
df_features = df[['PulsesAmpl', 'PulsesTime', 'Xrel', 'Yrel', 'Zrel']]
data = df_features.to_numpy()[:,:5]
for i in range(len(data)):
    data[i] = data[i, :]
    for j in range(len(data[i])):
        data[i, j] = data[i, j].round(3).astype(np.float32)

# %%
df['num_signal_hits'].value_counts(sort=True)[0:10]
# Out:
# shape: (10, 2)
# ┌─────────────────┬───────┐
# │ num_signal_hits ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ 3               ┆ 5207  │
# │ 2               ┆ 4390  │
# │ 4               ┆ 4307  │
# │ 5               ┆ 3191  │
# │ 0               ┆ 3149  │
# │ 6               ┆ 2392  │
# │ 7               ┆ 1765  │
# │ 8               ┆ 1357  │
# │ 9               ┆ 1037  │
# │ 10              ┆ 781   │
# └─────────────────┴───────┘

# %%
df['num_signal_strings'].value_counts(sort=True)[0:10]
# Out:
# shape: (9, 2)
# ┌────────────────────┬───────┐
# │ num_signal_strings ┆ count │
# │ ---                ┆ ---   │
# │ i8                 ┆ u32   │
# ╞════════════════════╪═══════╡
# │ 1                  ┆ 9993  │
# │ 2                  ┆ 9761  │
# │ 3                  ┆ 5074  │
# │ 0                  ┆ 3149  │
# │ 4                  ┆ 2371  │
# │ 5                  ┆ 1328  │
# │ 6                  ┆ 643   │
# │ 7                  ┆ 269   │
# │ 8                  ┆ 92    │
# └────────────────────┴───────┘

# %%
with h5.File(h5_file_path) as hf:
    print(hf['muatm/raw/labels/part_10762'].keys())
    print(hf['muatm/raw/data/part_10762'].keys())
    labels = hf['muatm/raw/labels/part_10761/data'][:]
    h5ev_starts = hf['muatm/raw/ev_starts/part_10762/data'][:]
    h5data_flat = hf['muatm/raw/data/part_10762/data'][:]

h5data = [[],[],[],[],[]]
for s,e in zip(h5ev_starts[:-1], h5ev_starts[1:]):
    for i in range(len(h5data)):
        h5data[i].append(h5data_flat[s:e,i].round(3))
h5data = np.array(h5data, dtype='O').T
# Out:
# <KeysViewHDF5 ['data']>
# <KeysViewHDF5 ['data']>

# %%
# Times
h5data[1,1][0:10], data[1,1][0:10]
# Out:
# (array([-2728.46 , -2557.722, -2551.978, -2354.059, -2130.664, -1992.022,
#         -1890.892, -1793.888, -1726.919, -1625.827], dtype=float32),
#  array([-2728.46 , -2557.721, -2551.977, -2354.058, -2130.664, -1992.022,
#         -1890.892, -1793.888, -1726.918, -1625.827], dtype=float32))

# %%
# Qs
h5data[1,0][0:10], data[1,0][0:10]
# Out:
# (array([0.63 , 0.819, 0.749, 0.662, 1.234, 1.294, 1.045, 0.699, 1.132,
#         0.643], dtype=float32),
#  array([0.63 , 0.819, 0.749, 0.662, 1.234, 1.294, 1.045, 0.699, 1.132,
#         0.643], dtype=float32))

# %%
def my_agg(data):
    value = np.diff(data).sum() + data[0]*1e4 + data[1]*1e6
    return value

arrs_sorted = sorted(data[:,1], key=my_agg)
h5arrs_sorted = sorted(h5data[:,1], key=my_agg)

# %%
for i, (arr, h5arr) in enumerate(zip(arrs_sorted, h5arrs_sorted)):
    if len(arr) == len(h5arr) and ((arr-h5arr)**2).sum()>1e-1:
        print(f"{i=}, {arr=}, \n{h5arr=}")
        print(f"{my_agg(arr)=}, \n{my_agg(h5arr)=}")
        print(f"{arr.shape=}, {h5arr.shape=}")
        print(f"{((arr-h5arr)**2).sum()=}")
        continue
# Out:
# i=2175, arr=array([-2630.371, -2598.865, -2396.391, -2308.823, -2247.485, -2197.076,
#        -1919.729, -1669.882, -1667.429, -1564.576, -1487.358, -1427.581,
#        -1390.628, -1351.047, -1157.54 , -1136.591,  -919.79 ,  -815.798,
#         -798.572,  -728.664,  -645.649,  -632.026,  -599.049,  -525.31 ,
#         -495.513,  -490.935,  -348.245,  -269.398,  -176.272,  -143.892,
#          -36.839,   -17.866,   -16.823,   128.367,   129.689,   178.543,
#          192.816,   209.107,   231.153,   282.911,   308.423,   355.39 ,
#          362.344,   432.697,   473.945,   482.917,   510.471,   551.416,
#          863.865,   873.032,   875.494,   929.326,  1011.585,  1036.494,
#         1170.086,  1193.737,  1205.948,  1258.761,  1418.798,  1456.963,
#         1488.867,  1501.834,  1535.239,  1551.148,  1558.062,  1896.847,
#         2184.203,  2312.502,  2322.261,  2336.764], dtype=float32),
# h5arr=array([-2601.876, -2599.15 , -2421.2  , -2418.695, -2309.146, -2294.953,
#        -2293.828, -2280.088, -2212.338, -2181.204, -2069.782, -2031.193,
#        -1872.847, -1672.984, -1379.294, -1334.21 , -1214.098, -1194.072,
#        -1060.905,  -971.417,  -908.097,  -903.838,  -843.539,  -708.56 ,
#         -686.603,  -598.09 ,  -569.878,  -450.949,  -434.197,  -415.939,
#         -383.513,  -206.895,  -194.725,  -179.452,   -55.092,    11.801,
#           71.354,    81.917,   123.629,   156.899,   166.301,   386.349,
#          748.621,   936.841,  1059.368,  1167.648,  1220.896,  1271.19 ,
#         1346.357,  1347.782,  1380.614,  1381.968,  1432.647,  1473.071,
#         1499.822,  1499.894,  1523.005,  1669.977,  1745.635,  1758.719,
#         1796.362,  1884.912,  1898.556,  1922.803,  2021.396,  2089.646,
#         2159.387,  2225.605,  2231.444,  2260.232], dtype=float32)
# my_agg(arr)=np.float32(-2625163500.0),
# my_agg(h5arr)=np.float32(-2625163800.0)
# arr.shape=(70,), h5arr.shape=(70,)
# ((arr-h5arr)**2).sum()=np.float32(8611635.0)
# i=2176, arr=array([-2601.876, -2599.149, -2421.2  , -2418.695, -2309.146, -2294.953,
#        -2293.827, -2280.088, -2212.338, -2181.204, -2069.782, -2031.193,
#        -1872.847, -1672.984, -1379.294, -1334.209, -1214.098, -1194.072,
#        -1060.905,  -971.417,  -908.097,  -903.838,  -843.539,  -708.56 ,
#         -686.603,  -598.09 ,  -569.877,  -450.949,  -434.197,  -415.938,
#         -383.513,  -206.895,  -194.725,  -179.452,   -55.092,    11.801,
#           71.354,    81.917,   123.629,   156.899,   166.301,   386.349,
#          748.621,   936.841,  1059.368,  1167.648,  1220.896,  1271.19 ,
#         1346.357,  1347.782,  1380.614,  1381.968,  1432.647,  1473.071,
#         1499.822,  1499.894,  1523.005,  1669.977,  1745.636,  1758.719,
#         1796.362,  1884.912,  1898.557,  1922.804,  2021.396,  2089.646,
#         2159.387,  2225.605,  2231.444,  2260.232], dtype=float32),
# h5arr=array([-2630.371, -2598.865, -2396.391, -2308.823, -2247.485, -2197.076,
#        -1919.729, -1669.881, -1667.429, -1564.576, -1487.358, -1427.581,
#        -1390.628, -1351.047, -1157.54 , -1136.591,  -919.79 ,  -815.798,
#         -798.572,  -728.663,  -645.649,  -632.026,  -599.049,  -525.31 ,
#         -495.513,  -490.935,  -348.245,  -269.398,  -176.272,  -143.892,
#          -36.839,   -17.866,   -16.823,   128.368,   129.689,   178.543,
#          192.816,   209.107,   231.153,   282.911,   308.423,   355.39 ,
#          362.344,   432.697,   473.945,   482.917,   510.471,   551.416,
#          863.865,   873.032,   875.494,   929.326,  1011.585,  1036.494,
#         1170.086,  1193.738,  1205.948,  1258.761,  1418.799,  1456.963,
#         1488.867,  1501.834,  1535.239,  1551.148,  1558.062,  1896.847,
#         2184.203,  2312.503,  2322.261,  2336.764], dtype=float32)
# my_agg(arr)=np.float32(-2625162800.0),
# my_agg(h5arr)=np.float32(-2625163500.0)
# arr.shape=(70,), h5arr.shape=(70,)
# ((arr-h5arr)**2).sum()=np.float32(8611637.0)
# i=8658, arr=array([-2458.131, -2439.796, -2403.237, -2245.122, -2178.706, -2096.585,
#        -2085.546, -2074.398, -2054.393, -2041.434, -1935.86 , -1909.438,
#        -1906.19 , -1855.755, -1771.094, -1757.252, -1641.221, -1267.664,
#        -1005.406,  -997.818,  -864.72 ,  -828.106,  -684.798,  -612.068,
#         -466.569,  -466.151,  -451.503,  -444.272,  -348.557,  -207.581,
#           -5.113,    52.222,    57.095,   133.94 ,   160.685,   215.733,
#          336.483,   440.225,   653.708,   702.149,   705.804,   771.811,
#          804.748,   818.205,   880.577,  1034.124,  1120.487,  1223.782,
#         -460.603,  -372.391,  -330.838,  -308.288,  -268.244,  -234.15 ,
#         -186.514,  -172.017,  -124.326,   -47.996,    22.543,   156.16 ,
#          179.949,   187.467,   209.38 ,   213.861,   256.079,   449.546,
#          466.791,   468.008,   609.417,   685.938,   791.148,   888.698,
#          979.939,   995.408,  1076.606,  1102.887,  1153.784,  1301.484,
#         1347.673,  1447.065,  1537.464,  1686.234,  1732.13 ,  1743.669,
#         1866.804,  1964.055,  1985.659,  2090.05 ], dtype=float32)
# my_agg(arr)=np.float32(-2407757600.0),
# my_agg(h5arr)=np.float32(-2407757000.0)
# arr.shape=(58,), h5arr.shape=(58,)
# ((arr-h5arr)**2).sum()=np.float32(2026145.4)
# i=14603, arr=array([-2415.324, -2349.899, -2178.162, -2173.672, -1840.426, -1786.779,
#        -1670.213, -1481.298, -1470.687, -1457.313, -1258.401, -1186.981,
#        -1080.664, -1007.219,  -989.488,  -837.047,  -705.749,  -528.601,
#         -476.201,  -403.957,  -335.421,  -310.874,  -257.834,  -228.148,
#         -180.178,  -154.147,   -55.266,   -33.624,     5.006,     6.402,
#           15.671,    37.849,    56.92 ,    62.403,    71.149,    88.495,
#          135.213,   174.905,   227.173,   308.818,   392.248,   437.298,
#          445.017,   476.046,   480.648,   507.889,   550.996,   573.261,
#          789.488,   820.775,   833.323,   986.762,  1020.157,  1027.31 ,
#         1054.747,  1496.475,  1560.897,  1659.19 ,  1840.65 ,  1881.761,
#         2093.321,  2224.21 ,  2236.226,  2274.864], dtype=float32),
# h5arr=array([-2416.545, -2349.887, -2244.887, -2112.65 , -2111.032, -2011.877,
#        -1974.562, -1898.256, -1893.965, -1882.18 , -1783.092, -1713.853,
#        -1698.474, -1654.496, -1601.513, -1582.754, -1162.088, -1148.059,
#        -1089.533, -1000.042,  -921.24 ,  -880.572,  -844.665,  -558.945,
#         -396.189,  -390.091,  -371.197,  -361.18 ,  -181.556,  -171.675,
#           51.291,    94.256,   131.203,   147.113,   201.518,   241.307,
#          264.681,   630.236,   718.82 ,   792.61 ,   883.04 ,   887.196,
#          965.89 ,   990.722,  1028.64 ,  1096.352,  1136.331,  1163.379,
#         1225.844,  1263.362,  1485.61 ,  1521.619,  1583.547,  1638.551,
#         1766.587,  1768.203,  1822.158,  1987.894,  1993.646,  2114.018,
#         2118.218,  2136.81 ,  2140.191,  2416.207], dtype=float32)
# my_agg(arr)=np.float32(-2374047500.0),
# my_agg(h5arr)=np.float32(-2374047500.0)
# arr.shape=(64,), h5arr.shape=(64,)
# ((arr-h5arr)**2).sum()=np.float32(11598201.0)
# i=14604, arr=array([-2416.545, -2349.886, -2244.887, -2112.65 , -2111.032, -2011.877,
#        -1974.562, -1898.255, -1893.965, -1882.18 , -1783.092, -1713.853,
#        -1698.474, -1654.496, -1601.512, -1582.754, -1162.088, -1148.058,
#        -1089.533, -1000.042,  -921.24 ,  -880.572,  -844.665,  -558.944,
#         -396.189,  -390.091,  -371.197,  -361.179,  -181.556,  -171.675,
#           51.292,    94.257,   131.203,   147.113,   201.518,   241.307,
#        -3.725060e+02, -3.242920e+02, -1.766680e+02, -5.757300e+01,
#        -2.815200e+01, -1.477000e+00,  3.610400e+01,  4.786500e+01,
#         6.049500e+01,  1.007790e+02,  1.643810e+02,  1.958360e+02,
#         2.581820e+02,  3.470110e+02,  4.295080e+02,  6.203610e+02,
#         7.811960e+02,  8.624500e+02,  8.848420e+02,  9.497090e+02,
#         1.105600e+03,  1.187915e+03,  1.261932e+03,  1.268158e+03,
#         1.345909e+03,  1.443731e+03,  1.611296e+03,  1.766414e+03,
#         1.769698e+03,  1.861232e+03,  1.971543e+03,  1.984247e+03,
#         2.000521e+03,  2.190889e+03,  2.400492e+03], dtype=float32)
# my_agg(arr)=np.float32(-2334002400.0),
# my_agg(h5arr)=np.float32(-2334001400.0)
# arr.shape=(55,), h5arr.shape=(55,)
# ((arr-h5arr)**2).sum()=np.float32(1227022.9)
# i=17340, arr=array([-2.380343e+03, -2.310203e+03, -2.152276e+03, -2.054884e+03,
#        -2.028888e+03, -1.969997e+03, -1.711848e+03, -1.612891e+03,
#        -1.609331e+03, -1.541620e+03, -1.534958e+03, -1.439258e+03,
#        -1.240811e+03, -1.173909e+03, -1.110258e+03, -1.005606e+03,
#        -1.000306e+03, -9.430870e+02, -7.350850e+02, -3.920700e+02,
#        -3.725060e+02, -3.242920e+02, -1.766680e+02, -5.757300e+01,
#        -2.815200e+01, -1.477000e+00,  3.610400e+01,  4.786400e+01,
#         6.049500e+01,  1.007790e+02,  1.643800e+02,  1.958360e+02,
#         2.581820e+02,  3.470110e+02,  4.295080e+02,  6.203610e+02,
#         7.811960e+02,  8.624500e+02,  8.848420e+02,  9.497090e+02,
#         1.105600e+03,  1.187915e+03,  1.261932e+03,  1.268158e+03,
#         1.345909e+03,  1.443731e+03,  1.611296e+03,  1.766414e+03,
#         1.769698e+03,  1.861232e+03,  1.971543e+03,  1.984247e+03,
#         2.000521e+03,  2.190889e+03,  2.400492e+03], dtype=float32),
# h5arr=array([-2347.341, -2310.533, -2274.547, -2044.686, -1999.994, -1826.93 ,
#        -1817.139, -1751.362, -1721.781, -1707.378, -1703.478, -1654.406,
#        -1533.158, -1226.457, -1135.404, -1040.869,  -900.3  ,  -876.279,
#         -748.535,  -738.028,  -633.843,  -500.656,  -234.646,  -168.478,
#         -104.482,   -23.016,    65.737,    75.373,   142.546,   199.746,
#          311.774,   396.82 ,   448.782,   566.439,   640.093,   736.37 ,
#          750.764,   767.42 ,   888.937,   931.784,  1064.43 ,  1179.423,
#         1204.106,  1238.387,  1338.127,  1417.421,  1419.826,  1527.387,
#         1932.996,  2166.978,  2243.298,  2244.75 ,  2255.27 ,  2336.464,
#         2532.277], dtype=float32)
# my_agg(arr)=np.float32(-2334001400.0),
# my_agg(h5arr)=np.float32(-2334001400.0)
# arr.shape=(55,), h5arr.shape=(55,)
# ((arr-h5arr)**2).sum()=np.float32(1227022.5)
# i=21119, arr=array([-2375.487, -2253.672, -2220.766, -2151.341, -2115.672, -1940.842,
#        -1870.325, -1857.032, -1712.783, -1681.36 , -1613.984, -1298.018,
#        -1231.687, -1212.307, -1118.772, -1036.083,  -671.556,  -668.264,
#         -452.009,  -397.057,  -388.12 ,  -325.884,  -248.595,  -232.139,
#         -231.079,  -222.761,  -141.06 ,   -93.678,   -18.613,    12.407,
#           70.008,   207.544,   449.978,   457.325,   457.658,   466.648,
#          475.983,   505.493,   694.425,  1059.07 ,  1407.588,  1514.658,
#         1585.703,  1613.665,  1638.687,  1710.861,  1788.6  ,  1796.314,
#         2100.786,  2161.416,  2265.774,  2383.216,  2471.781,  2485.334],
#       dtype=float32),
# h5arr=array([-2394.583, -2253.481, -2076.952, -2004.303, -1803.482, -1768.476,
#        -1570.35 , -1522.909, -1499.704, -1493.101, -1484.737, -1223.054,
#        -1121.137, -1038.859,  -929.233,  -861.827,  -823.94 ,  -807.291,
#         -706.318,  -695.469,  -511.308,  -315.394,  -282.804,  -227.378,
#           23.155,    55.877,    90.111,   181.156,   229.324,   233.684,
#          279.65 ,   362.695,   436.974,   556.395,   571.426,   578.28 ,
#          595.414,   742.237,   783.649,   785.01 ,   944.9  ,  1124.02 ,
#         1139.997,  1238.09 ,  1281.225,  1401.532,  1511.422,  1558.232,
#         1639.863,  1900.228,  1962.816,  2272.62 ,  2450.531,  2485.579],
#       dtype=float32)
# my_agg(arr)=np.float32(-2277422000.0),
# my_agg(h5arr)=np.float32(-2277421800.0)
# arr.shape=(54,), h5arr.shape=(54,)
# ((arr-h5arr)**2).sum()=np.float32(2882952.2)
# i=21120, arr=array([-2394.583, -2253.481, -2076.953, -2004.304, -1803.482, -1768.476,
#        -1570.351, -1522.909, -1499.705, -1493.101, -1484.738, -1223.055,
#        -1121.138, -1038.859,  -929.234,  -861.827,  -823.94 ,  -807.291,
#         -706.318,  -695.469,  -511.308,  -315.394,  -282.804,  -227.379,
#           23.155,    55.877,    90.111,   181.156,   229.324,   233.684,
#          279.649,   362.695,   436.974,   556.395,   571.426,   578.279,
#          595.414,   742.237,   783.648,   785.01 ,   944.9  ,  1124.02 ,
#         1139.997,  1238.09 ,  1281.225,  1401.532,  1511.422,  1558.232,
#         1639.863,  1900.228,  1962.816,  2272.62 ,  2450.531,  2485.579],
#       dtype=float32),
# h5arr=array([-2375.486, -2253.671, -2220.766, -2151.341, -2115.671, -1940.842,
#        -1870.324, -1857.032, -1712.782, -1681.36 , -1613.984, -1298.018,
#        -1231.686, -1212.306, -1118.772, -1036.083,  -671.555,  -668.263,
#         -452.008,  -397.056,  -388.119,  -325.884,  -248.595,  -232.138,
#         -231.078,  -222.761,  -141.059,   -93.678,   -18.612,    12.408,
#           70.009,   207.544,   449.978,   457.326,   457.659,   466.649,
#          475.983,   505.494,   694.425,  1059.07 ,  1407.588,  1514.658,
#         1585.704,  1613.665,  1638.687,  1710.862,  1788.601,  1796.314,
#         2100.786,  2161.417,  2265.774,  2383.216,  2471.782,  2485.334],
#       dtype=float32)
# my_agg(arr)=np.float32(-2277421800.0),
# my_agg(h5arr)=np.float32(-2277420800.0)
# arr.shape=(54,), h5arr.shape=(54,)
# ((arr-h5arr)**2).sum()=np.float32(2882947.8)
# i=26435, arr=array([-2393.732, -2159.626, -2104.98 , -2079.371, -1998.957, -1893.844,
#        -1868.309, -1755.401, -1741.002, -1736.498, -1715.132, -1570.407,
#        -1474.527, -1428.363, -1379.74 , -1126.338, -1099.73 , -1044.852,
#         -948.973,  -908.046,  -840.659,  -805.945,  -710.188,  -660.549,
#         -652.333,  -562.094,  -495.838,  -436.937,  -313.786,  -131.668,
#          -84.089,   -30.922,    79.008,   101.308,   129.436,   318.24 ,
#          505.24 ,   759.873,   760.237,   790.812,   945.575,   950.959,
#          978.992,  1014.051,  1047.005,  1058.191,  1147.474,  1154.971,
#         1244.113,  1263.586,  1266.92 ,  1386.698,  1703.371,  1774.897,
#         1966.983,  1986.031,  1986.034,  2147.756,  2264.099,  2423.578,
#         2484.417,  2512.956], dtype=float32),
# h5arr=array([-2176.427, -2161.798, -2034.277, -2011.026, -1986.196, -1867.129,
#        -1852.109, -1760.923, -1753.116, -1739.292, -1705.784, -1566.718,
#        -1534.344, -1392.263, -1124.082, -1100.577, -1060.054, -1014.163,
#         -956.923,  -953.683,  -906.062,  -895.566,  -841.641,  -815.511,
#         -805.955,  -787.325,  -698.584,  -648.443,  -629.528,  -559.975,
#         -476.797,  -345.483,  -335.461,  -293.804,   202.324,   236.138,
#          251.233,   343.681,   564.531,   570.054,   885.254,  1047.336,
#         1057.812,  1073.577,  1151.22 ,  1215.682,  1296.243,  1366.471,
#         1403.871,  1456.24 ,  1666.494,  1737.633,  1846.974,  1972.898,
#         2105.365,  2125.869,  2297.076,  2440.162,  2524.906,  2555.631,
#         2664.064,  2732.286], dtype=float32)
# my_agg(arr)=np.float32(-2183558400.0),
# my_agg(h5arr)=np.float32(-2183557600.0)
# arr.shape=(62,), h5arr.shape=(62,)
# ((arr-h5arr)**2).sum()=np.float32(2465971.0)
# i=26436, arr=array([-2176.427, -2161.798, -2034.277, -2011.026, -1986.196, -1867.129,
#        -1852.109, -1760.923, -1753.116, -1739.292, -1705.785, -1566.718,
#        -1534.344, -1392.263, -1124.082, -1100.577, -1060.054, -1014.163,
#         -956.923,  -953.683,  -906.062,  -895.566,  -841.642,  -815.511,
#         -805.955,  -787.325,  -698.584,  -648.443,  -629.528,  -559.975,
#         -476.798,  -345.484,  -335.461,  -293.804,   202.324,   236.138,
#          251.233,   343.681,   564.531,   570.054,   885.254,  1047.336,
#         1057.812,  1073.576,  1151.219,  1215.682,  1296.242,  1366.471,
#         1403.871,  1456.24 ,  1666.494,  1737.633,  1846.974,  1972.897,
#         2105.365,  2125.869,  2297.076,  2440.162,  2524.906,  2555.631,
#         2664.064,  2732.286], dtype=float32),
# h5arr=array([-2393.732, -2159.625, -2104.979, -2079.37 , -1998.957, -1893.844,
#        -1868.309, -1755.401, -1741.002, -1736.498, -1715.132, -1570.407,
#        -1474.527, -1428.363, -1379.739, -1126.338, -1099.73 , -1044.852,
#         -948.973,  -908.046,  -840.659,  -805.944,  -710.188,  -660.548,
#         -652.332,  -562.093,  -495.837,  -436.936,  -313.785,  -131.668,
#          -84.088,   -30.922,    79.009,   101.308,   129.436,   318.241,
#          505.24 ,   759.873,   760.237,   790.812,   945.575,   950.96 ,
#          978.992,  1014.051,  1047.005,  1058.192,  1147.475,  1154.971,
#         1244.113,  1263.586,  1266.92 ,  1386.699,  1703.372,  1774.897,
#         1966.983,  1986.031,  1986.034,  2147.757,  2264.1  ,  2423.579,
#         2484.418,  2512.957], dtype=float32)
# my_agg(arr)=np.float32(-2183557600.0),
# my_agg(h5arr)=np.float32(-2183557400.0)
# arr.shape=(62,), h5arr.shape=(62,)
# ((arr-h5arr)**2).sum()=np.float32(2465971.8)

# %%
i = 26436
for j in range(i-2,i+2):
    print(arrs_sorted[j][0:10]) 
print('\n')
for j in range(i-2,i+2):
    print(h5arrs_sorted[j][0:10])
# Out:
# [-2225.977 -2161.316 -2153.547 -2147.274 -2133.664 -1971.273 -1887.603
#  -1779.586 -1725.048 -1597.324]
# [-2393.732 -2159.626 -2104.98  -2079.371 -1998.957 -1893.844 -1868.309
#  -1755.401 -1741.002 -1736.498]
# [-2176.427 -2161.798 -2034.277 -2011.026 -1986.196 -1867.129 -1852.109
#  -1760.923 -1753.116 -1739.292]
# [-2402.808 -2159.516 -2125.385 -2116.757 -1995.362 -1935.743 -1824.303
#  -1819.113 -1814.608 -1787.646]
#
#
# [-2225.977 -2161.315 -2153.547 -2147.273 -2133.664 -1971.273 -1887.603
#  -1779.586 -1725.048 -1597.324]
# [-2176.427 -2161.798 -2034.277 -2011.026 -1986.196 -1867.129 -1852.109
#  -1760.923 -1753.116 -1739.292]
# [-2393.732 -2159.625 -2104.979 -2079.37  -1998.957 -1893.844 -1868.309
#  -1755.401 -1741.002 -1736.498]
# [-2402.808 -2159.516 -2125.385 -2116.757 -1995.362 -1935.743 -1824.303
#  -1819.113 -1814.608 -1787.646]

# %%
a = np.diff(arrs_sorted[216][1])
a.sort()
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[331], line 1
# ----> 1 a = np.diff(arrs_sorted[216][1])
#       2 a.sort()
#       3 a
#
# File ~/Baikal-ML/venv/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:1481, in diff(a, n, axis, prepend, append)
#    1479 nd = a.ndim
#    1480 if nd == 0:
# -> 1481     raise ValueError("diff requires input that is at least one dimensional")
#    1482 axis = normalize_axis_index(axis, nd)
#    1484 combined = []
#
# ValueError: diff requires input that is at least one dimensional

# %%
a = np.diff(arrs_sorted[216, 1])
a.sort()
a
# Out:
# array([  0.5910034,   0.8789673,   1.0019836,   1.1629639,   2.3130493,
#          2.3510132,   2.95401  ,   3.4079895,   4.1779785,   4.8720703,
#          5.083008 ,   9.335022 ,  11.273926 ,  11.653992 ,  13.247925 ,
#         15.374001 ,  15.73584  ,  15.984009 ,  19.317993 ,  22.425999 ,
#         23.002197 ,  26.475002 ,  26.87207  ,  27.608994 ,  27.935059 ,
#         31.291992 ,  32.484985 ,  33.572    ,  35.866943 ,  36.264893 ,
#         36.458008 ,  36.78296  ,  41.02002  ,  41.833984 ,  42.659058 ,
#         43.593018 ,  44.25598  ,  44.50415  ,  54.20105  ,  54.867004 ,
#         56.682983 ,  58.386017 ,  61.830017 ,  65.63701  ,  72.32202  ,
#         73.01404  ,  94.808    ,  95.19214  ,  95.52307  ,  97.47693  ,
#         99.25806  ,  99.301025 , 103.37201  , 117.12097  , 124.645996 ,
#        139.20404  , 140.97894  , 142.85693  , 144.11899  , 148.71103  ,
#        149.29993  , 154.20288  , 159.59302  , 181.36804  , 188.32898  ,
#        194.76196  , 225.10901  , 245.63904  , 273.69598  , 280.23895  ],
#       dtype=float32)

# %%
arr**2
# Out:
# array([3882.5364  , 1767.2776  ,   14.0625  ,   10.969344, 1767.2776  ,
#        2371.3977  ,   14.0625  ,   14.0625  ,   10.969344, 1767.2776  ,
#          10.969344, 3873.444   ,   10.969344,   14.0625  ,   14.0625  ,
#        2371.3977  ,   10.969344,  322.38202 , 3882.5364  ,   10.969344,
#          10.969344, 1767.2776  , 3873.444   , 1767.2776  , 1767.2776  ,
#        3873.444   ,   14.0625  , 1767.2776  , 3873.444   ,   14.0625  ],
#       dtype=float32)

# %%
for arr in data['PulsesAmpl'].to_numpy()[0:100]:
    isin = False
    for h5arr in np.array(h5data, dtype='O'):
        if np.array_equal(arr.round(2), h5arr.round(1)):
            isin = True
            break
    if not isin:
        print(f"Not found {arr=}")
        break

if isin: print("Ok")
# Out:
# Ok

# %%
arrs_sorted[0]
# Out:
# array([0.45707488, 0.54925996, 1.1084076 , 1.0147641 , 1.3423243 ,
#        0.45414194, 1.3642868 , 0.1923474 , 1.2159913 , 0.9707401 ,
#        0.46262902, 1.3109553 , 0.46508235, 0.3268888 , 1.2114706 ,
#        0.68017316, 0.47373992, 4.4352856 , 2.4288769 , 0.8066567 ,
#        0.77942866, 0.0568226 , 0.92032105, 0.01334081, 1.1223383 ,
#        0.7534976 , 1.1192905 , 1.0429873 , 0.5466738 , 0.9732134 ,
#        0.2414653 , 0.8178828 , 0.4950653 , 0.9499361 , 0.57954675,
#        0.7830459 ], dtype=float32)

# %%
h5arrs_sorted = sorted(, key=np.sum)
h5arrs_sorted[0]
# Out:
# array([0.45707488, 0.54925996, 1.1084076 , 1.0147641 , 1.3423243 ,
#        0.45414194, 1.3642868 , 0.1923474 , 1.2159913 , 0.9707401 ,
#        0.46262902, 1.3109553 , 0.46508235, 0.3268888 , 1.2114706 ,
#        0.68017316, 0.47373992, 4.4352856 , 2.4288769 , 0.8066567 ,
#        0.77942866, 0.0568226 , 0.92032105, 0.01334081, 1.1223383 ,
#        0.7534976 , 1.1192905 , 1.0429873 , 0.5466738 , 0.9732134 ,
#        0.2414653 , 0.8178828 , 0.4950653 , 0.9499361 , 0.57954675,
#        0.7830459 ], dtype=float32)

# %%
np.array_equal(arrs_sorted, h5arrs_sorted)
# Out:
# False
