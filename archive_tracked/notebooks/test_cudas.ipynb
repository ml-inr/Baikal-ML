# %%
import torch

torch.cuda.list_gpu_processes()
# Out:
# 'pynvml module not found, please install nvidia-ml-py'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.rand(100, device='cuda:3')
# Out:
# tensor([6.2689e-02, 1.6310e-01, 1.6374e-02, 6.4918e-02, 7.9726e-01, 8.9373e-01,
#         2.9856e-01, 9.1976e-01, 3.7972e-01, 5.7108e-01, 7.2253e-01, 8.1571e-01,
#         7.3957e-01, 5.5514e-01, 7.4701e-01, 7.1988e-01, 8.3775e-01, 8.0896e-01,
#         2.5247e-01, 1.6041e-01, 1.2502e-01, 3.0807e-01, 2.4839e-01, 1.0540e-01,
#         9.5369e-03, 5.7811e-01, 1.5672e-01, 7.7301e-01, 6.9484e-01, 5.5847e-01,
#         1.7363e-01, 3.8874e-01, 1.4137e-01, 7.3082e-01, 8.8876e-01, 6.9469e-01,
#         4.2661e-01, 7.0376e-01, 5.0099e-01, 2.2784e-01, 1.6961e-01, 2.7221e-01,
#         8.7359e-01, 1.6057e-01, 3.7305e-01, 8.7931e-01, 5.7028e-01, 8.6496e-01,
#         7.2948e-01, 8.3387e-01, 4.6548e-01, 9.8195e-01, 6.6503e-01, 5.8814e-01,
#         2.4624e-01, 4.9052e-01, 9.4529e-01, 8.6315e-01, 8.8201e-01, 8.8028e-04,
#         8.0957e-01, 9.1959e-01, 9.1341e-01, 3.1715e-01, 9.8214e-01, 4.4272e-01,
#         3.7899e-01, 7.5729e-01, 9.9586e-01, 7.9405e-01, 5.1342e-01, 1.1584e-01,
# ...

# %%
import numpy as np

d1 = {
    "features": np.array([0,1,2,3,4])
}

features = d1['features'].copy()
features = features*2

{**d1, "features": features}
# Out:
# {'features': array([0, 2, 4, 6, 8])}
